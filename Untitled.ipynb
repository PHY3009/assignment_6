# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import HTML
# %matplotlib inline

# %%
filename = 'anes_specialstudy_2012_directdem.dta'
voted = pd.read_stata(filename)
voted.head(n=5)
voted.shape
# Out:
# (5415, 1037)

# %%
voter = voted['dd_rvote2012_x']

# %%
plt.plot(voted.post_happy_timing)

# %%
democrats = voted[voted.dd_presvote2012_x == '1. Barack Obama (Democrat)']

# %%
democrats
# Out:
#                                              dd_version  dd_caseid caseid  \
# 0     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20001   3001
# 2     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20003   3005
# 3     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20004   3009
# 8     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20009   3026
# 10    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20011   3028
# 15    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20016   3039
# 16    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20017   3042
# 19    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20020   3049
# 20    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20021   3051
# 23    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20024   3056
# 33    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20034   3083
# 34    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20035   3084
# ...

# %%
"""im having troubles that i will have to talk to you independantly about"""
# Out:
# 'im having troubles that i will have to talk to you independantly about'

# %%
"""I can remmebr most things but I cant figure out how to add a new colum in time to complete this assignment. realstically Its a time managment thing. also this data set is fricking annoying and I will ask you about how to make a new coloumn that I can compare to another new colomn like amount of democrats ve rebublicans and strangth of party affiliation and pre vvs post weight."""
# Out:
# 'I can remmebr most things but I cant figure out how to add a new colum in time to complete this assignment. realstically Its a time managment thing. also this data set is fricking annoying and I will ask you about how to make a new coloumn that I can compare to another new colomn like amount of democrats ve rebublicans and strangth of party affiliation and pre vvs post weight.'

# %%
"""realistically those were things I was trying to do but kept getting caught up with the indexing and not being able to .count words...."""
# Out:
# 'realistically those were things I was trying to do but kept getting caught up with the indexing and not being able to .count words....'

# %%
voted = voted[voted.dd_rvote2012_x == '1. Voted']

# %%
voted[voted.dd_presvote2012_x == '1. Barack Obama (Democrat)']
# Out:
#                                              dd_version  dd_caseid caseid  \
# 0     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20001   3001
# 2     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20003   3005
# 3     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20004   3009
# 8     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20009   3026
# 10    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20011   3028
# 15    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20016   3039
# 16    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20017   3042
# 19    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20020   3049
# 20    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20021   3051
# 23    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20024   3056
# 33    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20034   3083
# 34    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20035   3084
# ...
