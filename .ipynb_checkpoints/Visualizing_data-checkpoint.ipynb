# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing data
data = pd.read_csv('pop_data.csv')
#data appears to have three different estimates of population for each age, one after another on the same column.
#So I've split them into three different variables. 
cut_data_1 = data[0:101]
cut_data_2 = data[102:203]
cut_data_3 = data[204:305]

# %%
plt.tight_layout
plt.suptitle('Three Population Estimates From the 2010 US Census')
#subplot 1
plt.subplot(1,3,1)
plt.bar(cut_data_1.AGE,cut_data_1.CENSUS2010POP)
plt.xlim(0,100)
#plt.xlabel('Age')
plt.ylabel('Population')
#subplot 2
plt.subplot(1,3,2)
plt.xlim(0,100)
plt.bar(cut_data_2.AGE,cut_data_2.CENSUS2010POP)
plt.xlabel('Age')

#subplot 3
plt.subplot(1,3,3)
plt.xlim(0,100)
plt.bar(cut_data_3.AGE,cut_data_3.CENSUS2010POP)
# Out:
# <Container object of 101 artists>

# %%
#This is the data for the 2010 census visualized in a bar graph using cut_1 of the data.
plt.bar(cut_data_1.AGE, cut_data_1.CENSUS2010POP)
plt.xlim(0,100)
plt.xlabel('Age')
plt.ylabel('Population')
plt.title('Population by Age in the 2010 US Census')

# %%
plt.boxplot(cut_data_3.iloc[30,3:])
plt.tight_layout
plt.ylabel('Population')
plt.title('Distribution of Estimated Number of 30 Year Olds From 2010-2014')

# %% [markdown]
# The first thing I figured out about the data was that it seemed to be repeated three times, so I made the first figure to see if they had any drastic differences. When they did not I proceeded to work on one cut at a time. The second figure shows the population data from the 2010 US census. You can note peaks around 20 and 50, and a sharp decline after about 60. My final figure shows the distribution in the numbers of 30 year olds counted in 2010, and estimated till 2014. It doesn't really seem to show that much variation, as could be seen if looking at an age the baby boomers are cureently moving through.
